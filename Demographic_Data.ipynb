# %%
import pandas as pd
import numpy as np

# %%
demographicsData = pd.read_csv('Demographic_Data/DemoData.csv')
demographicsData.head()
# Out:
#         GEO_ID                  NAME                               DP05_0001E  \
# 0           id  Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1  0400000US01               Alabama                                  4903185
# 2  0400000US02                Alaska                                   731545
# 3  0400000US04               Arizona                                  7278717
# 4  0400000US05              Arkansas                                  3017804
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           *****
# 2                                           *****
# 3                                           *****
# 4                                           *****
#
#                               DP05_0001PE  \
# 0  Percent!!SEX AND AGE!!Total population
# 1                                 4903185
# 2                                  731545
# ...

# %%
# Functions box

# create function to delete columns based on name
def deleteColumnNames(table, str):
    index = []
    for name in table.columns:
        if str in name:
            index.append(name)
    table = table.drop(columns = index, axis = 0)
    return table;
# created a function to create a table using specific columns from meta table
def grabSpecificColumns(table, str):
    index = ['Geographic Area Name']
    for name in table.columns:
        if str in name:
            index.append(name)
    table = table[index]
    return table

# convert dtype of columns to a specfic one other thatn Geographic Area name
def convertDtypes(table, str):
    #creating a list of columns to iterate through so I can turn strings into ints
    listOfColumns = table.columns.to_list()
    listOfColumns.remove('Geographic Area Name')
    table[listOfColumns] = table[listOfColumns].astype(str)
    return table

# %%
# remove id column
demographicsData = deleteColumnNames(demographicsData, 'GEO_ID')

demographicsData.head()
# Out:
#                    NAME                               DP05_0001E  \
# 0  Geographic Area Name  Estimate!!SEX AND AGE!!Total population
# 1               Alabama                                  4903185
# 2                Alaska                                   731545
# 3               Arizona                                  7278717
# 4              Arkansas                                  3017804
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           *****
# 2                                           *****
# 3                                           *****
# 4                                           *****
#
#                               DP05_0001PE  \
# 0  Percent!!SEX AND AGE!!Total population
# 1                                 4903185
# 2                                  731545
# 3                                 7278717
# 4                                 3017804
#
# ...

# %%
titleArray = []
for title in demographicsData.loc[0]:
    title = title.replace('!!', ' ')
    titleArray.append(title)
demographicsData.loc[0] = titleArray
demographicsData.head()
# Out:
#                    NAME                             DP05_0001E  \
# 0  Geographic Area Name  Estimate SEX AND AGE Total population
# 1               Alabama                                4903185
# 2                Alaska                                 731545
# 3               Arizona                                7278717
# 4              Arkansas                                3017804
#
#                                      DP05_0001M  \
# 0  Margin of Error SEX AND AGE Total population
# 1                                         *****
# 2                                         *****
# 3                                         *****
# 4                                         *****
#
#                             DP05_0001PE  \
# 0  Percent SEX AND AGE Total population
# 1                               4903185
# 2                                731545
# 3                               7278717
# 4                               3017804
#
# ...

# %%
demographicsData.columns = demographicsData.loc[0]
demographicsData = deleteColumnNames(demographicsData, 'Margin of Error')
demographicsData = demographicsData.drop(labels=0, axis=0)

# %%
demographicsData.head()
# Out:
# 0 Geographic Area Name Estimate SEX AND AGE Total population  \
# 1              Alabama                               4903185
# 2               Alaska                                731545
# 3              Arizona                               7278717
# 4             Arkansas                               3017804
# 5           California                              39512223
#
# 0 Percent SEX AND AGE Total population  \
# 1                              4903185
# 2                               731545
# 3                              7278717
# 4                              3017804
# 5                             39512223
#
# 0 Estimate SEX AND AGE Total population Male  \
# 1                                    2369611
# 2                                     380433
# 3                                    3620935
# 4                                    1474705
# 5                                   19640794
#
# 0 Percent SEX AND AGE Total population Male  \
# ...

# %%
# The value (X) was the equivalent of NaN values in these tables so I removed them
index = []
for column in demographicsData:
    if '(X)' in demographicsData[column].loc[1]:
        index.append(column)
demographicsData = demographicsData.drop(columns=index, axis = 0)
demographicsData.head()
# Out:
# 0 Geographic Area Name Estimate SEX AND AGE Total population  \
# 1              Alabama                               4903185
# 2               Alaska                                731545
# 3              Arizona                               7278717
# 4             Arkansas                               3017804
# 5           California                              39512223
#
# 0 Percent SEX AND AGE Total population  \
# 1                              4903185
# 2                               731545
# 3                              7278717
# 4                              3017804
# 5                             39512223
#
# 0 Estimate SEX AND AGE Total population Male  \
# 1                                    2369611
# 2                                     380433
# 3                                    3620935
# 4                                    1474705
# 5                                   19640794
#
# 0 Percent SEX AND AGE Total population Male  \
# ...

# %%
# columns with N value had race information which is not what i needed in my analysis so I am removing those columns
index = []
for column in demographicsData:
    if 'N' in demographicsData[column].loc[1]:
        index.append(column)
demographicsData = demographicsData.drop(columns=index, axis = 0)
demographicsData.head()
# Out:
# 0 Geographic Area Name Estimate SEX AND AGE Total population  \
# 1              Alabama                               4903185
# 2               Alaska                                731545
# 3              Arizona                               7278717
# 4             Arkansas                               3017804
# 5           California                              39512223
#
# 0 Percent SEX AND AGE Total population  \
# 1                              4903185
# 2                               731545
# 3                              7278717
# 4                              3017804
# 5                             39512223
#
# 0 Estimate SEX AND AGE Total population Male  \
# 1                                    2369611
# 2                                     380433
# 3                                    3620935
# 4                                    1474705
# 5                                   19640794
#
# 0 Percent SEX AND AGE Total population Male  \
# ...
