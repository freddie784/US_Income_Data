# %%
import pandas as pd
import numpy as np

# %%
income_table = pd.read_csv('productDownload_2022-01-24T145502/State_by_State_Income_Info.csv')

# %%
# Functions box

# create function to delete columns based on name
def deleteColumnNames(table, str):
    index = []
    for name in table.columns:
        if str in name:
            index.append(name)
    table = table.drop(columns = index, axis = 0)
    return table;
# created a function to create a table using specific columns from meta table
def grabSpecificColumns(table, str):
    index = ['Geographic Area Name']
    for name in table.columns:
        if str in name:
            index.append(name)
    table = table[index]
    return table

# convert dtype of columns to a specfic one other thatn Geographic Area name
def convertDtypes(table, str):
    #creating a list of columns to iterate through so I can turn strings into ints
    listOfColumns = table.columns.to_list()
    listOfColumns.remove('Geographic Area Name')
    table[listOfColumns] = table[listOfColumns].astype(str)
    return table

# %%
income_table.head()
# Out:
#         GEO_ID                  NAME               S1901_C01_001E  \
# 0           id  Geographic Area Name  Estimate!!Households!!Total
# 1  0400000US01               Alabama                      1897576
# 2  0400000US02                Alaska                       252199
# 3  0400000US04               Arizona                      2670441
# 4  0400000US05              Arkansas                      1163647
#
#                        S1901_C01_001M  \
# 0  Margin of Error!!Households!!Total
# 1                               10370
# 2                                3658
# 3                               12014
# 4                                8530
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             8.1
# 2                                             4.1
# 3                                             5.9
# 4                                             7.1
#
# ...

# %%
# remove id column
income_table = deleteColumnNames(income_table, 'GEO_ID')

income_table.head()
# Out:
#                    NAME               S1901_C01_001E  \
# 0  Geographic Area Name  Estimate!!Households!!Total
# 1               Alabama                      1897576
# 2                Alaska                       252199
# 3               Arizona                      2670441
# 4              Arkansas                      1163647
#
#                        S1901_C01_001M  \
# 0  Margin of Error!!Households!!Total
# 1                               10370
# 2                                3658
# 3                               12014
# 4                                8530
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             8.1
# 2                                             4.1
# 3                                             5.9
# 4                                             7.1
#
#                                       S1901_C01_002M  \
# ...

# %%
# replace !! with a space in the column names
rowOne =income_table.loc[0]
titleArray = []
for title in rowOne:
    title = title.replace('!!', ' ')
    titleArray.append(title)
income_table.loc[0] = titleArray
income_table.head()
# Out:
#                    NAME             S1901_C01_001E  \
# 0  Geographic Area Name  Estimate Households Total
# 1               Alabama                    1897576
# 2                Alaska                     252199
# 3               Arizona                    2670441
# 4              Arkansas                    1163647
#
#                      S1901_C01_001M  \
# 0  Margin of Error Households Total
# 1                             10370
# 2                              3658
# 3                             12014
# 4                              8530
#
#                                 S1901_C01_002E  \
# 0  Estimate Households Total Less than $10,000
# 1                                          8.1
# 2                                          4.1
# 3                                          5.9
# 4                                          7.1
#
#                                       S1901_C01_002M  \
# 0  Margin of Error Households Total Less than $10...
# ...

# %%
# replace column names with first row names
income_table.columns = income_table.loc[0]

# %%
# drop duplicate column names
income_table = income_table.drop(labels=0, axis=0)

# %%
income_table.head()
# Out:
# 0 Geographic Area Name Estimate Households Total  \
# 1              Alabama                   1897576
# 2               Alaska                    252199
# 3              Arizona                   2670441
# 4             Arkansas                   1163647
# 5           California                  13157873
#
# 0 Margin of Error Households Total  \
# 1                            10370
# 2                             3658
# 3                            12014
# 4                             8530
# 5                            23844
#
# 0 Estimate Households Total Less than $10,000  \
# 1                                         8.1
# 2                                         4.1
# 3                                         5.9
# 4                                         7.1
# 5                                         4.6
#
# 0 Margin of Error Households Total Less than $10,000  \
# 1                                                0.3
# 2                                                0.6
# ...

# %%
# delete margin of error columns
noMarginofError = deleteColumnNames(income_table, 'Margin of Error')
noMarginofError.head()
# Out:
# 0 Geographic Area Name Estimate Households Total  \
# 1              Alabama                   1897576
# 2               Alaska                    252199
# 3              Arizona                   2670441
# 4             Arkansas                   1163647
# 5           California                  13157873
#
# 0 Estimate Households Total Less than $10,000  \
# 1                                         8.1
# 2                                         4.1
# 3                                         5.9
# 4                                         7.1
# 5                                         4.6
#
# 0 Estimate Households Total $10,000 to $14,999  \
# 1                                          5.5
# 2                                          3.2
# 3                                          3.5
# 4                                          6.0
# 5                                          3.7
#
# 0 Estimate Households Total $15,000 to $24,999  \
# ...

# %%
cleanTable = deleteColumnNames(noMarginofError, 'PERCENT ALLOCATED')
cleanTable = convertDtypes(cleanTable, 'float')
cleanTable.head()
# Out:
# 0 Geographic Area Name  Estimate Households Total  \
# 1              Alabama                  1897576.0
# 2               Alaska                   252199.0
# 3              Arizona                  2670441.0
# 4             Arkansas                  1163647.0
# 5           California                 13157873.0
#
# 0  Estimate Households Total Less than $10,000  \
# 1                                          8.1
# 2                                          4.1
# 3                                          5.9
# 4                                          7.1
# 5                                          4.6
#
# 0  Estimate Households Total $10,000 to $14,999  \
# 1                                           5.5
# 2                                           3.2
# 3                                           3.5
# 4                                           6.0
# 5                                           3.7
#
# 0  Estimate Households Total $15,000 to $24,999  \
# ...

# %%
# creating a table to see what columns I have not used
currentTable = cleanTable

# %%
medianTable = grabSpecificColumns(cleanTable, 'Median')
currentTable = deleteColumnNames(currentTable, 'Median')
medianTable.head()
# Out:
# 0 Geographic Area Name  Estimate Households Median income (dollars)  \
# 1              Alabama                                      51734.0
# 2               Alaska                                      75463.0
# 3              Arizona                                      62055.0
# 4             Arkansas                                      48952.0
# 5           California                                      80440.0
#
# 0  Estimate Families Median income (dollars)  \
# 1                                    66171.0
# 2                                    91971.0
# 3                                    74468.0
# 4                                    62387.0
# 5                                    91377.0
#
# 0  Estimate Married-couple families Median income (dollars)  \
# 1                                            81393.0
# 2                                           106046.0
# 3                                            87708.0
# 4                                            73796.0
# ...

# %%
meanTable = grabSpecificColumns(cleanTable, 'Mean')
currentTable = deleteColumnNames(currentTable, 'Mean')
meanTable.head()
# Out:
# 0 Geographic Area Name  Estimate Households Mean income (dollars)  \
# 1              Alabama                                    71478.0
# 2               Alaska                                    98504.0
# 3              Arizona                                    84438.0
# 4             Arkansas                                    68219.0
# 5           California                                   113563.0
#
# 0  Estimate Families Mean income (dollars)  \
# 1                                  85630.0
# 2                                 115639.0
# 3                                  97314.0
# 4                                  81640.0
# 5                                 126354.0
#
# 0  Estimate Married-couple families Mean income (dollars)  \
# 1                                           101086.0
# 2                                           130245.0
# 3                                           112220.0
# 4                                            94373.0
# ...

# %%
householdsTable = grabSpecificColumns(cleanTable, 'Estimate Households Total')
currentTable = deleteColumnNames(currentTable, 'Estimate Households Total')
householdsTable.head()
# Out:
# 0 Geographic Area Name  Estimate Households Total  \
# 1              Alabama                  1897576.0
# 2               Alaska                   252199.0
# 3              Arizona                  2670441.0
# 4             Arkansas                  1163647.0
# 5           California                 13157873.0
#
# 0  Estimate Households Total Less than $10,000  \
# 1                                          8.1
# 2                                          4.1
# 3                                          5.9
# 4                                          7.1
# 5                                          4.6
#
# 0  Estimate Households Total $10,000 to $14,999  \
# 1                                           5.5
# 2                                           3.2
# 3                                           3.5
# 4                                           6.0
# 5                                           3.7
#
# 0  Estimate Households Total $15,000 to $24,999  \
# ...

# %%
familiesTable = grabSpecificColumns(cleanTable, 'Estimate Families Total')
currentTable = deleteColumnNames(currentTable, 'Estimate Families Total')
familiesTable.head()
# Out:
# 0 Geographic Area Name  Estimate Families Total  \
# 1              Alabama                1237883.0
# 2               Alaska                 163134.0
# 3              Arizona                1740704.0
# 4             Arkansas                 755305.0
# 5           California                8972643.0
#
# 0  Estimate Families Total Less than $10,000  \
# 1                                        4.6
# 2                                        2.0
# 3                                        3.9
# 4                                        3.9
# 5                                        2.9
#
# 0  Estimate Families Total $10,000 to $14,999  \
# 1                                         2.6
# 2                                         1.8
# 3                                         1.9
# 4                                         3.1
# 5                                         1.9
#
# 0  Estimate Families Total $15,000 to $24,999  \
# 1                                         7.6
# ...

# %%
nonfamilyTable = grabSpecificColumns(cleanTable, 'Estimate Nonfamily households Total')
currentTable = deleteColumnNames(currentTable, 'Estimate Nonfamily households Total')
nonfamilyTable.head()
# Out:
# 0 Geographic Area Name  Estimate Nonfamily households Total  \
# 1              Alabama                             659693.0
# 2               Alaska                              89065.0
# 3              Arizona                             929737.0
# 4             Arkansas                             408342.0
# 5           California                            4185230.0
#
# 0  Estimate Nonfamily households Total Less than $10,000  \
# 1                                               15.6
# 2                                                8.6
# 3                                               11.1
# 4                                               14.3
# 5                                                9.4
#
# 0  Estimate Nonfamily households Total $10,000 to $14,999  \
# 1                                               11.1
# 2                                                6.3
# 3                                                6.7
# 4                                               11.7
# ...

# %%
marriedCoupleTable = grabSpecificColumns(cleanTable, 'Estimate Married-couple')
currentTable = deleteColumnNames(currentTable, 'Estimate Married-couple')
marriedCoupleTable.head()
# Out:
# 0 Geographic Area Name  Estimate Married-couple families Total  \
# 1              Alabama                                892050.0
# 2               Alaska                                124608.0
# 3              Arizona                               1272331.0
# 4             Arkansas                                553179.0
# 5           California                               6490186.0
#
# 0  Estimate Married-couple families Total Less than $10,000  \
# 1                                                1.5
# 2                                                0.5
# 3                                                1.8
# 4                                                1.4
# 5                                                1.3
#
# 0  Estimate Married-couple families Total $10,000 to $14,999  \
# 1                                                1.4
# 2                                                1.3
# 3                                                1.2
# ...

# %%
#test table to see what other categories are left in the data
currentTable.head()
# Out:
# 0 Geographic Area Name
# 1              Alabama
# 2               Alaska
# 3              Arizona
# 4             Arkansas
# 5           California

# %%
marriedCoupleTable.dtypes
# Out:
# 0
# Geographic Area Name                                            object
# Estimate Married-couple families Total                         float64
# Estimate Married-couple families Total Less than $10,000       float64
# Estimate Married-couple families Total $10,000 to $14,999      float64
# Estimate Married-couple families Total $15,000 to $24,999      float64
# Estimate Married-couple families Total $25,000 to $34,999      float64
# Estimate Married-couple families Total $35,000 to $49,999      float64
# Estimate Married-couple families Total $50,000 to $74,999      float64
# Estimate Married-couple families Total $75,000 to $99,999      float64
# Estimate Married-couple families Total $100,000 to $149,999    float64
# Estimate Married-couple families Total $150,000 to $199,999    float64
# Estimate Married-couple families Total $200,000 or more        float64
# Estimate Married-couple families Median income (dollars)       float64
# ...
